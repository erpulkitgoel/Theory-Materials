# %% [markdown]
# # Activation Function in Convolutional Neural Networks

# %% [markdown]
# In an artificial neural network, the activation function of a neuron defines the output of that neuron given  a set of inputs.
# ![image.png](attachment:image.png)
#
# Biologically inspired by the activity in our brain, where each neuron is activated, by some stimuli

# %% [markdown]
# # 1) Sigmoid Function
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. ReLU ( Rectified Linear Unit)
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Identity Function
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Binary Step Activation function
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5.  Tanh ( tan h) Activation Function
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Leaky ReLU
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. Softmax Function
# Softmax Activation function generates the scaled input into probability units so that the combined probability of the input set is equal to 100%.
